# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
pip install transformers_stream_generator einops

# %%
pip install transformers_stream_generator -U

# %%
pip install tiktoken

# %%
text = """Dear WidgetCorp,
I am writing to express my deep disappointment with your service regarding my recent order (Order
#98765). I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday
was on March 15th. Despite your website promising delivery within three days, the product arrived
only yesterday, missing her birthday entirely.
I attempted to contact your customer service multiple times for an explanation and to expedite the
delivery, but to no avail. My calls and emails went unanswered, leaving me in a difficult position with
no gift for Emily’s special day.
This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. I
expect a prompt explanation and an assurance that such delays will not occur in the future.
Sincerely,
Jane Doe """

# %%
model_path = "Nexusflow/NexusRaven-V2-13B" 
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(
    model_path, torch_dtype=torch.float16, device_map='auto')# ,trust_remote_code=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/985 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/623 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/671 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/29.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.90G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
prompt = 'What was the reason for the customer disappointment with WidgetCorp?\nA:'
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
generation_output = model.generate(input_ids=input_ids, max_new_tokens=100)
print(tokenizer.decode(generation_output[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 2024-01-30 09:45:46.698271: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 09:45:46.698375: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-30 09:45:47.008644: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# <s> What was the reason for the customer disappointment with WidgetCorp?
# A: The customer was disappointed with WidgetCorp because the company failed to deliver the promised product on time. The customer had ordered a product that was supposed to be delivered within a week, but it was not delivered until two weeks later. This caused the customer to miss the deadline for the project and to lose the opportunity to use the product.
# B: The customer was disappointed with WidgetCorp because the company failed to provide the promised level of quality. The customer had ordered a product that

# %%
prompt = '• How did WidgetCorp customer service respond to the customer inquiries about the late delivery?\nA:'
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
generation_output = model.generate(input_ids=input_ids, max_new_tokens=500)
print(tokenizer.decode(generation_output[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> • How did WidgetCorp customer service respond to the customer inquiries about the late delivery?
# A: The customer service team at WidgetCorp responded to the customer inquiries about the late delivery by apologizing for the inconvenience and offering to provide a refund or a replacement widget. The team also offered to provide additional information about the late delivery, such as the estimated delivery date and the reason for the delay.
# • How did the customer service team at WidgetCorp handle the customer complaint about the quality of the widgets?
# A: The customer service team at WidgetCorp handled the customer complaint about the quality of the widgets by apologizing for the issue and offering to provide a replacement widget. The team also offered to provide additional information about the quality of the widgets, such as the materials used and the manufacturing process.
# • How did the customer service team at WidgetCorp handle the customer complaint about the price of the widgets?
# A: The customer service team at WidgetCorp handled the customer complaint about the price of the widgets by apologizing for the issue and offering to provide a discount or a refund. The team also offered to provide additional information about the price of the widgets, such as the cost of the materials and the manufacturing process.
# • How did the customer service team at WidgetCorp handle the customer complaint about the customer service?
# A: The customer service team at WidgetCorp handled the customer complaint about the customer service by apologizing for the issue and offering to provide additional training or support for the customer. The team also offered to provide additional information about the customer service, such as the hours of operation and the contact information for the customer service team.</s>

# %%
query = "identify the entities in standard NER terminology in the following text: "
prompt = query + "\n" +text
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
generation_output = model.generate(
    input_ids=input_ids, max_new_tokens=500)
print(tokenizer.decode(generation_output[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> identify the entities in standard NER terminology in the following text:
# Dear WidgetCorp,
# I am writing to express my deep disappointment with your service regarding my recent order (Order
# #98765). I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday
# was on March 15th. Despite your website promising delivery within three days, the product arrived
# only yesterday, missing her birthday entirely.
# I attempted to contact your customer service multiple times for an explanation and to expedite the
# delivery, but to no avail. My calls and emails went unanswered, leaving me in a difficult position with
# no gift for Emily’s special day.
# This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. I
# expect a prompt explanation and an assurance that such delays will not occur in the future.
# Sincerely,
# Jane Doe
# Call: identify_entities(text='Dear WidgetCorp, I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely. I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day. This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. I expect a prompt explanation and an assurance that such delays will not occur in the future. Sincerely, Jane Doe')<bot_end>
# Thought: The function call `identify_entities(text='Dear WidgetCorp, I am writing to express my deep disappointment with your service regarding my recent order (Order #98765). I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday was on March 15th. Despite your website promising delivery within three days, the product arrived only yesterday, missing her birthday entirely. I attempted to contact your customer service multiple times for an explanation and to expedite the delivery, but to no avail. My calls and emails went unanswered, leaving me in a difficult position with no gift for Emily’s special day. This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. I expect a prompt explanation and an assurance that such delays will not occur in the future. Sincerely, Jane Doe')` answers the question by identifying the entities in the text using the NER terminology.
#
# The function call passes the text as an argument to the `identify_entities` function, which is defined in the `ner` module. The `identify_entities` function uses the `spacy` library to identify the entities in the text and return them as a list of tuples, where each tuple contains the entity type and the text that represents the entity.

# %%
query = "summarize the following text: "
prompt = query + "\n" + text
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
generation_output = model.generate(
    input_ids=input_ids, max_new_tokens=300)
print(tokenizer.decode(generation_output[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> summarize the following text:
# Dear WidgetCorp,
# I am writing to express my deep disappointment with your service regarding my recent order (Order
# #98765). I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday
# was on March 15th. Despite your website promising delivery within three days, the product arrived
# only yesterday, missing her birthday entirely.
# I attempted to contact your customer service multiple times for an explanation and to expedite the
# delivery, but to no avail. My calls and emails went unanswered, leaving me in a difficult position with
# no gift for Emily’s special day.
# This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. I
# expect a prompt explanation and an assurance that such delays will not occur in the future.
# Sincerely,
# Jane Doe

# %%
query = "Translate the following text to French: "
prompt = query + "\n" + text
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
generation_output = model.generate(
    input_ids=input_ids, max_new_tokens=900)
print(tokenizer.decode(generation_output[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> Translate the following text to French:
# Dear WidgetCorp,
# I am writing to express my deep disappointment with your service regarding my recent order (Order
# #98765). I had ordered the "SuperWidget" as a birthday gift for my daughter, Emily, whose birthday
# was on March 15th. Despite your website promising delivery within three days, the product arrived
# only yesterday, missing her birthday entirely.
# I attempted to contact your customer service multiple times for an explanation and to expedite the
# delivery, but to no avail. My calls and emails went unanswered, leaving me in a difficult position with
# no gift for Emily’s special day.
# This experience has left a sour taste, and I am reconsidering future purchases from WidgetCorp. I
# expect a prompt explanation and an assurance that such delays will not occur in the future.
# Sincerely,
# Jane Doe

# %%
text = """Chère WidgetCorp,
Je vous écris pour exprimer ma vive déception quant à votre service en ce qui concerne mon dernier achat (commande #98765). J'avais commandé le "SuperWidget" en tant que cadeau d'anniversaire pour ma fille Emily, dont le jour des naissances était le 15 mars. Bien que votre site web promettait une livraison dans les trois jours, le produit n'a été livré qu'hier, manquant ainsi son anniversaire.
J'ai tenté de contacter votre service client plusieurs fois pour obtenir une explication et pour accélérer la livraison, mais sans succès. Mes appels et mes e-mails restaient sans réponse, laissant dans une situation difficile sans cadeau pour l'anniversaire d'Emily.
Cette expérience a laissé un goût amer, et je me demande si je vais continuer à faire des achats chez WidgetCorp dans l'avenir. Je vous attend une explication rapide et une assurance que de tels retards ne se reproduiront pas dans l'avenir.
Sincèrement,
Jane Doe"""

# Translate the text from French to English
query = "Translate the following text to English: "
prompt = query + "\n" + text
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
generation_output = model.generate(
    input_ids=input_ids, max_new_tokens=900)
translated_text = tokenizer.decode(generation_output[0])
print (translated_text)
